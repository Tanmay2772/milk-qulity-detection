# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('milknew.csv')

# %%
df
# Out:
#       Temprature  Fat    Grade
# 0             35     1    high
# 1             36     0    high
# 2             70     1     low
# 3             34     0     low
# 4             37     0  medium
# ...          ...   ...     ...
# 1054          45     0  medium
# 1055          38     1    high
# 1056          40     1     low
# 1057          43     1    high
# 1058          55     1     low
#
# [1059 rows x 3 columns]

# %%
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 739   6.5          38      1     0     1          0     255  medium
# 888   4.5          38      0     1     1          1     255     low
# 152   9.5          34      1     1     0          1     255     low
# 862   9.0          43      1     1     1          1     248     low
# 719   6.5          36      0     0     1          0     255  medium
# 866   6.6          38      0     0     0          0     255  medium
# 81    6.6          37      1     0     1          0     255    high
# 397   6.8          36      0     1     1          0     253    high
# 1054  6.7          45      1     1     0          0     247  medium
# 775   4.7          38      1     0     1          0     255     low

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x="Temprature",y="Fat")

# %%
df = df.drop(columns=["Taste"])

# %%
df = df.drop(columns=["Odor"])

# %%
df = df.drop(columns=["pH"])

# %%
df.sample(10)
# Out:
#      Temprature  Fat   Turbidity  Colour   Grade
# 917          41     0          0     247  medium
# 303          40     1          1     255    high
# 35           45     1          1     255    high
# 238          65     0          0     255     low
# 607          41     0          0     247  medium
# 435          38     0          0     255  medium
# 726          45     1          1     250    high
# 741          50     1          0     245     low
# 849          45     0          0     240  medium
# 534          38     1          1     255    high

# %%
df = df.drop(columns=["Turbidity"])

# %%
df=df.drop(columns=["Colour"])

# %%
df.sample(10)
# Out:
#      Temprature  Fat  Grade
# 786          50     1   low
# 242          40     0   low
# 850          65     0   low
# 141          38     1  high
# 900          55     1   low
# 551          40     1   low
# 997          40     1   low
# 722          38     1   low
# 645          36     1  high
# 475          55     1   low

# %%
#indepent
x=df.iloc[:,0:2]
#depentent
y=df.iloc[:,-1]

# %%
x
# Out:
#       Temprature  Fat
# 0             35     1
# 1             36     0
# 2             70     1
# 3             34     0
# 4             37     0
# ...          ...   ...
# 1054          45     0
# 1055          38     1
# 1056          40     1
# 1057          43     1
# 1058          55     1
#
# [1059 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_test
# Out:
# array([[-0.127584  ,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-0.61864845, -1.44711984],
#        [-0.42222267,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [ 0.06884177, -1.44711984],
#        [-0.42222267, -1.44711984],
#        [ 2.13131244,  0.69102777],
#        [-0.32400978, -1.44711984],
#        [-0.91328711,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.81507423,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 0.06884177,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 1.05097066,  0.69102777],
#        [-0.81507423, -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [-0.71686134,  0.69102777],
#        [-0.32400978,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [-1.0115    , -1.44711984],
#        [ 2.03309955, -1.44711984],
# ...

# %%
x_train
# Out:
#      Temprature  Fat
# 215          38     1
# 337          45     0
# 394          38     1
# 779          37     0
# 687          43     1
# ..          ...   ...
# 949          35     1
# 751          45     0
# 924          38     0
# 655          38     1
# 118          43     1
#
# [953 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.127584  ,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-0.61864845, -1.44711984],
#        [-0.42222267,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [ 0.06884177, -1.44711984],
#        [-0.42222267, -1.44711984],
#        [ 2.13131244,  0.69102777],
#        [-0.32400978, -1.44711984],
#        [-0.91328711,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.81507423,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 0.06884177,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 1.05097066,  0.69102777],
#        [-0.81507423, -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [-0.71686134,  0.69102777],
#        [-0.32400978,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [-1.0115    , -1.44711984],
#        [ 2.03309955, -1.44711984],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
# array([[-0.127584  ,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-0.61864845, -1.44711984],
#        [-0.42222267,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [ 0.06884177, -1.44711984],
#        [-0.42222267, -1.44711984],
#        [ 2.13131244,  0.69102777],
#        [-0.32400978, -1.44711984],
#        [-0.91328711,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.61864845,  0.69102777],
#        [-0.81507423,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 0.06884177,  0.69102777],
#        [-0.42222267,  0.69102777],
#        [ 1.05097066,  0.69102777],
#        [-0.81507423, -1.44711984],
#        [ 0.06884177,  0.69102777],
#        [-0.71686134,  0.69102777],
#        [-0.32400978,  0.69102777],
#        [-0.127584  ,  0.69102777],
#        [-1.0115    , -1.44711984],
#        [-1.0115    , -1.44711984],
#        [ 2.03309955, -1.44711984],
# ...

# %%
clf.predict(x_test)
# Out:
# array(['low', 'low', 'medium', 'high', 'high', 'medium', 'low', 'medium',
#        'medium', 'low', 'medium', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'low', 'medium', 'low', 'high', 'high', 'low',
#        'medium', 'medium', 'low', 'low', 'high', 'high', 'high', 'high',
#        'low', 'low', 'high', 'high', 'low', 'low', 'medium', 'medium',
#        'low', 'low', 'low', 'medium', 'low', 'high', 'high', 'high',
#        'medium', 'high', 'low', 'medium', 'medium', 'high', 'high',
#        'medium', 'medium', 'low', 'low', 'medium', 'medium', 'medium',
#        'medium', 'medium', 'high', 'high', 'low', 'low', 'low', 'medium',
#        'medium', 'low', 'medium', 'high', 'low', 'medium', 'low', 'low',
#        'low', 'low', 'high', 'medium', 'medium', 'low', 'high', 'high',
#        'high', 'medium', 'low', 'medium', 'low', 'high', 'low', 'medium',
#        'low', 'low', 'low', 'high', 'high', 'low', 'medium', 'high',
# ...

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6509433962264151

# %%
#svm acc
from sklearn.svm import SVC

# Initialize the model
model = SVC(kernel='linear', random_state=42)  # You could also try 'rbf' or 'poly' kernels
model.fit(x_train, y_train)

# Evaluate
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 59.43%

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier

# Initialize the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train, y_train)

# Evaluate
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 74.53%

# %%
#GradientBoosting
from sklearn.ensemble import GradientBoostingClassifier

# Initialize the model
model = GradientBoostingClassifier(random_state=42)
model.fit(x_train, y_train)

# Evaluate
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 74.53%

# %%
#k_neigh
from sklearn.neighbors import KNeighborsClassifier

# Initialize the model
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)

# Evaluate
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 68.87%

# %%
df.replace({"Grade":{'high':2,'medium':1,'low':0}},inplace=True)
# Out:
# <ipython-input-59-b50e15b92183>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Grade":{'high':2,'medium':1,'low':0}},inplace=True)

# %%
#XGBClassifier
from xgboost import XGBClassifier

# Initialize the model
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
model.fit(x_train, y_train)

# Evaluate
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# we need to give value 0,1,2 and our value in the format of the we can encode the value to the convert it into the
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-c6a6dfb16a3c> in <cell line: 6>()
#       4 # Initialize the model
#       5 model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
# ----> 6 model.fit(x_train, y_train)
#       7
#       8 # Evaluate
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#     727
#     728         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1489                 or not (classes == expected_classes).all()
#    1490             ):
# ...

# %%
import pickle
pickle.dump(clf,open('model.pkl','wb'))

# %% [markdown]
# # New Section
